# %% [markdown]
# # 📌 [Title — replace me]
#
# ![Topic](https://img.shields.io/badge/Topic-Replace%20Me-blue?style=flat-square)
# ![Category](https://img.shields.io/badge/Category-Replace%20Me-blueviolet?style=flat-square)
# ![Level](https://img.shields.io/badge/Level-Intermediate-yellow?style=flat-square)
# ![Last Updated](https://img.shields.io/badge/Updated-Month%20Year-blue?style=flat-square)
# <br>
# <br>
# <br>
# > <span style="font-size:20px;">**TL;DR** — One or two sentence summary of the concept and why it matters.</span>

# %% [markdown]
# ## Prerequisites
#
# | Requirement | Details |
# |-------------|---------|
# | Python | 3.10+ |
# | Libraries | `pip install ...` |
# | Concepts | List any background knowledge needed |

# %% [markdown]
# ---
# ## 1. Overview
#
# <!-- What is this concept? 2–4 sentences that a newcomer could understand.
#      Include: what problem it solves, why it exists, where it fits in the AI landscape. -->

# %% [markdown]
# _Replace this cell with your overview text._

# %% [markdown]
# ---
# ## 2. How It Works
#
# <!-- Break the concept into numbered steps or subsections.
#      Use diagrams (images from assets/) where helpful.
#      Each subsection should follow: description → danger/difficulty level → counter-technique or note -->

# %% [markdown]
# ### 2.1 [Step or Subtopic Name]
#
# _Describe the step or subtopic here._
#
# **Key property:** …
# **Note / Counter-technique:** …

# %% [markdown]
# ### 2.2 [Step or Subtopic Name]
#
# _Describe the step or subtopic here._

# %% [markdown]
# ---
# ## 3. Advantages & Limitations
#
# | | Aspect | Commentary |
# |--|--------|------------|
# | 🟢 | Advantage 1 | Why this is good |
# | 🟢 | Advantage 2 | Why this is good |
# | 🔴 | Limitation 1 | Why this is a concern |
# | 🔴 | Limitation 2 | Why this is a concern |

# %% [markdown]
# ---
# ## 4. Code Example
#
# > **Goal:** Describe what this code demonstrates in one sentence.

# %%
# ---------------------------------------------------------------------------
# [Section title]
# ---------------------------------------------------------------------------

# TODO: replace with your implementation
print("Hello, AI!")

# %% [markdown]
# ---
# ## 5. Key Takeaways
# <div style="font-size: 16px; line-height: 1.6;">
#
# - Takeaway 1
# - Takeaway 2
# - Takeaway 3
# - Takeaway 4
# - Takeaway 5
#
# </div>
